# %%
#import columns
import pandas as pd
import numpy as np
import csv

# %%
# Data set listing the interventions carried out by the Montreal Fire Department (MIS)
# including the location of interventions and units deployed - 2015 onwards.
df1 = pd.read_csv('data/incident_data/donneesouvertes-interventions-sim.csv')
df1.head()
# Out:
#    INCIDENT_NBR   CREATION_DATE_TIME      INCIDENT_TYPE_DESC  \
# 0          1168  2015-01-03T20:56:02       Premier répondant
# 1          1171  2015-01-03T21:03:52  Alarme privé ou locale
# 2          1172  2015-01-03T21:07:00       Premier répondant
# 3          1177  2015-01-03T21:41:46       Premier répondant
# 4          1178  2015-01-03T21:43:32    Aliments surchauffés
#
#   DESCRIPTION_GROUPE  CASERNE NOM_VILLE  \
# 0           1-REPOND       33  Montréal
# 1  Alarmes-incendies       22  Montréal
# 2           1-REPOND        9  Montréal
# 3           1-REPOND       37  Montréal
# 4           SANS FEU       16  Montréal
#
#                               NOM_ARROND  DIVISION  NOMBRE_UNITES  CIV  \
# 0                              Sud-Ouest         8            1.0  1.0
# 1                          Saint-Léonard         4            4.0  1.0
# 2  Villeray / St-Michel / Parc Extension         4            1.0  1.0
# 3  Villeray / St-Michel / Parc Extension         4            1.0  1.0
# 4                     Plateau Mont-Royal        11            5.0  1.0
#
#      MTM8_X     MTM8_Y  LONGITUDE   LATITUDE
# 0  297283.0  5035433.1 -73.596117  45.458786
# 1  299180.0  5049284.2 -73.572020  45.583442
# 2  297259.6  5046768.2 -73.596589  45.560784
# 3  294738.3  5044817.2 -73.628847  45.543197
# 4  298505.7  5042556.1 -73.580573  45.522895

# %%
# Data set listing the interventions carried out by the Montreal Fire Department (MIS)
# including the location of interventions and units deployed - 2005 to 2014
df2 = pd.read_csv('data/incident_data/donneesouvertes-interventions-sim-2005-2014.csv')
df2.head()
# Out:
#    INCIDENT_NBR   CREATION_DATE_TIME      INCIDENT_TYPE_DESC  \
# 0             1  2005-01-01 00:03:47              Inondation
# 1             2  2005-01-01 00:03:56  Alarme privé ou locale
# 2             3  2005-01-01 00:03:57  Alarme privé ou locale
# 3             4  2005-01-01 00:05:01              Inondation
# 4             5  2005-01-01 00:06:20              Inondation
#
#   DESCRIPTION_GROUPE  CASERNE      NOM_VILLE  \
# 0      Sans incendie       18  Montréal-Nord
# 1  Alarmes-incendies       10       Montréal
# 2  Alarmes-incendies       72  Saint-Laurent
# 3      Sans incendie       13       Montréal
# 4      Sans incendie       18  Montréal-Nord
#
#                                      NOM_ARROND  DIVISION   LATITUDE  \
# 0                                 Montréal-Nord        21  45.620274
# 1  Ville-Marie / Parc Jean-Drapeau / Centre-Sud        18  45.494087
# 2                                    St-Laurent        13  45.484406
# 3               Mercier / Hochelaga-Maisonneuve        23  45.541383
# 4                                 Montréal-Nord        21  45.611304
#
#    LONGITUDE  NOMBRE_UNITES
# 0 -73.619956            1.0
# 1 -73.582587            7.0
# 2 -73.693038            6.0
# 3 -73.545944            1.0
# 4 -73.632440            1.0

# %%
# drop columns that we don't need
df1.drop(['INCIDENT_NBR', 'CIV', 'MTM8_X', 'MTM8_Y'], axis=1, inplace=True)
df2.drop(['INCIDENT_NBR'], axis=1, inplace=True)

# %%
#merge the two datasets
df = pd.concat([df1, df2], ignore_index=True, sort=True)

# %%
# convert to datetime
df['CREATION_DATE_TIME'] =  pd.to_datetime(df['CREATION_DATE_TIME'], infer_datetime_format=True)

# %%
# use Date/Time to generate Month, DOW, Hour, and Date column
df['MONTH'] =  df['CREATION_DATE_TIME'].dt.month
df['DAY_OF_WEEK'] =  df['CREATION_DATE_TIME'].dt.dayofweek
df['HOUR_OF_DAY'] =  df['CREATION_DATE_TIME'].dt.hour
df['Date'] =  df['CREATION_DATE_TIME'].dt.date

# %%
# add a column to indicate 'Time of Day' - bracket into 6 hr brackets
tod_bins = [0, 6, 12, 18, 24]
tod_labels = ['Night', 'Morning','Afternoon','Evening']
hours = df['CREATION_DATE_TIME'].dt.hour
df['TIME_OF_DAY'] = pd.cut(hours, bins=tod_bins, labels=tod_labels, right=False)

# %%
df.NOM_VILLE.value_counts()
# Out:
# Montréal                   1252567
# Dollard-des-Ormeaux          27034
# Pointe-Claire                26388
# Westmount                    18049
# Dorval                       17749
# Mont-Royal                   14731
# Kirkland                      9952
# Beaconsfield                  9588
# Côte St-Luc                   8900
# Saint-Laurent                 6355
# Montréal-Est                  5819
# Montréal-Nord                 5033
# Lasalle                       4562
# Ste-Anne-de-Bellevue          4466
# Hampstead                     4176
# Saint-Léonard                 3816
# Verdun / Ïle-des-Soeurs       3721
# Pierrefonds                   3466
# Baie d'Urfé                   3246
# Lachine                       3245
# Montréal-Ouest                2789
# Outremont                     2615
# Anjou                         2343
# Senneville                    1022
# Ile-Bizard                     678
# Roxboro                        330
# Ste-Geneviève                  319
# Ile Dorval                      10
# Indéterminé                      4
# Laval                            3
# Saint-Hubert                     1
# Name: NOM_VILLE, dtype: int64

# %%
df.loc[df['NOM_VILLE'] == 'Indéterminé']
# Out:
#         CASERNE  CREATION_DATE_TIME           DESCRIPTION_GROUPE  DIVISION  \
# 357803       57 2018-07-19 05:15:35                     1-REPOND         0
# 359556       35 2018-12-12 09:32:13                     SANS FEU         0
# 686258       54 2007-12-19 08:15:33  Fausses alertes/annulations        13
# 738131       74 2008-08-30 21:29:12            Premier répondant        13
#
#                 INCIDENT_TYPE_DESC   LATITUDE  LONGITUDE  NOMBRE_UNITES  \
# 357803           Premier répondant  45.511787 -73.764875            2.0
# 359556      Assistance serv. muni.  45.557494 -73.673288            5.0
# 686258         Fausse alerte 10-19  45.401301 -73.957345            2.0
# 738131  Ac.véh./1R/s.v./V.R./29B/D  45.530144 -73.646591            5.0
#
#          NOM_ARROND    NOM_VILLE  MONTH  DAY_OF_WEEK  HOUR_OF_DAY        Date  \
# 357803  Indéterminé  Indéterminé      7            3            5  2018-07-19
# 359556  Indéterminé  Indéterminé     12            2            9  2018-12-12
# 686258  Indéterminé  Indéterminé     12            2            8  2007-12-19
# 738131  Indéterminé  Indéterminé      8            5           21  2008-08-30
#
#        TIME_OF_DAY
# 357803       Night
# 359556     Morning
# 686258     Morning
# 738131     Evening

# %%
# if city is undetermined, then so is arrondisement
# we are using the location for prediction so we can remove these four values
df.drop(df.loc[df['NOM_VILLE'] == 'Indéterminé'].index, inplace=True)

# %%
df.NOM_ARROND.value_counts()
# Out:
# Ville-Marie                                     146026
# Indéterminé                                     128162
# Mercier / Hochelaga-Maisonneuve                 107885
# Côte-des-Neiges / Notre-Dame-de-Grâce           107026
# Villeray / St-Michel / Parc Extension            96114
# Rosemont / Petite-Patrie                         94044
# Ahuntsic / Cartierville                          90608
# Plateau Mont-Royal                               84959
# Montréal-Nord                                    73058
# Rivière-des-Prairies / Pointe-aux-Trembles       64639
# Sud-Ouest                                        64006
# Saint-Laurent                                    61890
# Lasalle                                          50370
# Saint-Léonard                                    46148
# Verdun                                           38974
# Lachine                                          36323
# Anjou                                            30871
# Pierrefonds / Roxboro                            30235
# Ville-Marie / Parc Jean-Drapeau / Centre-Sud     15992
# Outremont                                        15883
# L'Ile-Bizard / Ste-Geneviève                      9847
# St-Laurent                                        6358
# Rivière-des-Prairies / P-A-T/Mtl-Est              6036
# Dollard-des-Ormeaux / Roxboro                     4837
# Pointe-Claire                                     4817
# St-Léonard                                        3831
# Verdun / Ïle-des-Soeurs                           3725
# Pierrefonds / Senneville                          3538
# Westmount                                         3375
# Côte St-Luc / Hampstead / Mtl-Ouest               3190
# Beaconsfield / Baie d'Urfé                        2403
# Dorval / Ile Dorval                               2369
# Mont-Royal                                        1999
# Kirkland                                          1812
# Ile-Bizard / Ste-Geneviève / Ste-A-de-B           1623
# Name: NOM_ARROND, dtype: int64

# %%
df.loc[df['NOM_ARROND'] == 'Indéterminé']
# Out:
#          CASERNE  CREATION_DATE_TIME DESCRIPTION_GROUPE  DIVISION  \
# 14            53 2015-01-04 15:35:19           AUTREFEU         2
# 16            63 2015-01-04 15:37:42           SANS FEU         3
# 23            54 2015-01-04 15:49:23           SANS FEU         2
# 24            55 2015-01-04 15:50:24           SANS FEU         2
# 33            76 2015-01-05 07:51:03           1-REPOND         9
# 37            53 2015-01-05 08:21:41           1-REPOND         2
# 50            78 2015-01-06 05:20:47           SANS FEU         4
# 54            63 2015-01-06 06:20:43  Alarmes-incendies         2
# 56            61 2015-01-06 06:25:45           1-REPOND         1
# 78            63 2015-01-07 21:28:13           SANS FEU         2
# 87            61 2015-01-07 22:13:31           1-REPOND         1
# 111           61 2015-01-09 17:40:26           1-REPOND         1
# 123           77 2015-01-01 17:15:48           1-REPOND         7
# 130           54 2015-01-01 17:51:06           SANS FEU         2
# 148           76 2015-01-02 21:18:17  Alarmes-incendies         9
# 172           55 2015-01-04 16:08:21           SANS FEU         2
# 174           55 2015-01-04 16:10:37           SANS FEU         2
# 181           74 2015-01-04 16:21:53           SANS FEU         3
# 182           55 2015-01-04 16:21:55           SANS FEU         2
# 195           54 2015-01-05 09:18:01           SANS FEU         2
# 203           63 2015-01-06 07:27:58           1-REPOND         2
# 111                   Premier répondant  45.495843 -73.789512            1.0
# 123                   Premier répondant  45.458387 -73.659617            1.0
# 130                Aliments surchauffés  45.448583 -73.881677            1.0
# 148           Appel de Cie de détection  45.489363 -73.617896            3.0
# 172               Problèmes électriques  45.448208 -73.800770            1.0
# 174                      10-22 sans feu  45.460522 -73.790542            4.0
# 181               Problèmes électriques  45.523243 -73.648375            1.0
# 182               Problèmes électriques  45.459455 -73.806144            1.0
# 195                      10-22 sans feu  45.448613 -73.889194            4.0
# 203                   Premier répondant  45.451499 -73.777598            1.0
# 206                   Premier répondant  45.415124 -73.922444            1.0
# 207                   Premier répondant  45.447956 -73.850301            1.0
# 211                   Premier répondant  45.409390 -73.913698            1.0
# 219                   Premier répondant  45.488080 -73.588052            1.0
# 248                          Inondation  45.453862 -73.658286            1.0
# 250                   Premier répondant  45.409931 -73.929302            1.0
# 262                      10-22 avec feu  45.482541 -73.591627            6.0
# 266                   Premier répondant  45.476673 -73.838380            1.0
# 269                   Premier répondant  45.467240 -73.846647            1.0
# ...                                 ...        ...        ...            ...
# 1442683    Matières dangereuses / 10-22  45.517173 -73.656579            6.0
# 1442696               Premier répondant  45.455084 -73.778933            1.0
# 1442704           Problèmes électriques  45.476371 -73.652246            1.0
# 1442706           Problèmes électriques  45.419426 -73.883253            1.0
# 1442711               Premier répondant  45.504349 -73.657324            1.0
# 1442715               Premier répondant  45.489111 -73.798649            1.0
# 1442724                  10-22 sans feu  45.471623 -73.838920            4.0
# 1442737               Premier répondant  45.488088 -73.808008            1.0
# 1442780               Premier répondant  45.484786 -73.592016            1.0
# 1442796               Premier répondant  45.463120 -73.829688            1.0
# 1442798  Fuite ext.:hydrocar. liq. div.  45.456741 -73.751413            1.0
# 1442812               Premier répondant  45.446348 -73.812971            1.0
# 1442823                  10-22 sans feu  45.427240 -73.836802            5.0
# 1442825                  10-22 sans feu  45.453658 -73.863578            5.0
# 1442837       Appel de Cie de détection  45.441107 -73.736183            5.0
# 1442843               Premier répondant  45.514192 -73.644399            1.0
# 1442861               Feu de cheminée *  45.463883 -73.860101            4.0
# 1442862                      Inondation  45.478391 -73.633960            1.0
# 1442865       Appel de Cie de détection  45.480059 -73.831270            3.0
# 1442871               Premier répondant  45.462305 -73.828264            1.0
# 1442878               Premier répondant  45.466673 -73.797341            1.0
# 1442892               Premier répondant  45.465774 -73.853707            1.0
# 1442901               Premier répondant  45.499093 -73.824127            1.0
# 1442906               Premier répondant  45.452008 -73.835146            1.0
# 1442914       Appel de Cie de détection  45.455849 -73.844848            5.0
# 1442942               Premier répondant  45.496952 -73.836526            1.0
# 1442951            Aliments surchauffés  45.472283 -73.660266            2.0
# 1442961      Ac.véh./1R/s.v./V.R./29B/D  45.484098 -73.584672            3.0
# 1442966               Premier répondant  45.425597 -73.881288            1.0
# 1442973               Premier répondant  45.425597 -73.881288            1.0
#
#           NOM_ARROND            NOM_VILLE  MONTH  DAY_OF_WEEK  HOUR_OF_DAY  \
# 1442961  Indéterminé            Westmount     12            2           22
# 1442966  Indéterminé         Beaconsfield     12            2           23
# 1442973  Indéterminé         Beaconsfield     12            2           23
#
#                Date TIME_OF_DAY
# 14       2015-01-04   Afternoon
# 16       2015-01-04   Afternoon
# 23       2015-01-04   Afternoon
# 24       2015-01-04   Afternoon
# 33       2015-01-05     Morning
# 37       2015-01-05     Morning
# 50       2015-01-06       Night
# 54       2015-01-06     Morning
# 56       2015-01-06     Morning
# 78       2015-01-07     Evening
# 87       2015-01-07     Evening
# 111      2015-01-09   Afternoon
# 123      2015-01-01   Afternoon
# 130      2015-01-01   Afternoon
# 148      2015-01-02     Evening
# 172      2015-01-04   Afternoon
# 174      2015-01-04   Afternoon
# 181      2015-01-04   Afternoon
# 182      2015-01-04   Afternoon
# 195      2015-01-05     Morning
# 203      2015-01-06     Morning
# 206      2015-01-06     Morning
# 207      2015-01-06     Morning
# 211      2015-01-07       Night
# 219      2015-01-07       Night
# 248      2015-01-08     Evening
# 250      2015-01-08     Evening
# 262      2015-01-01     Evening
# 266      2015-01-01     Evening
# 269      2015-01-01     Evening
# ...             ...         ...
# 1442683  2014-12-31       Night
# 1442696  2014-12-31     Morning
# 1442704  2014-12-31     Morning
# 1442706  2014-12-31     Morning
# 1442711  2014-12-31     Morning
# 1442715  2014-12-31     Morning
# 1442724  2014-12-31     Morning
# 1442737  2014-12-31     Morning
# 1442780  2014-12-31   Afternoon
# 1442796  2014-12-31   Afternoon
# 1442798  2014-12-31   Afternoon
# 1442812  2014-12-31   Afternoon
# 1442823  2014-12-31   Afternoon
# 1442825  2014-12-31   Afternoon
# 1442837  2014-12-31   Afternoon
# 1442843  2014-12-31   Afternoon
# 1442861  2014-12-31   Afternoon
# 1442862  2014-12-31   Afternoon
# 1442865  2014-12-31   Afternoon
# 1442871  2014-12-31     Evening
# 1442878  2014-12-31     Evening
# 1442892  2014-12-31     Evening
# 1442901  2014-12-31     Evening
# 1442906  2014-12-31     Evening
# 1442914  2014-12-31     Evening
# 1442942  2014-12-31     Evening
# 1442951  2014-12-31     Evening
# 1442961  2014-12-31     Evening
# 1442966  2014-12-31     Evening
# 1442973  2014-12-31     Evening
#
# [128162 rows x 15 columns]

# %%
# arrondisement is missing for cities that are not Montreal
# if arrondisement is undertermined, use the name of the city as the arrondisement
df.loc[df['NOM_ARROND']=='Indéterminé', 'NOM_ARROND'] = df['NOM_VILLE']

# %%
df.head()
# Out:
#    CASERNE  CREATION_DATE_TIME DESCRIPTION_GROUPE  DIVISION  \
# 0       33 2015-01-03 20:56:02           1-REPOND         8
# 1       22 2015-01-03 21:03:52  Alarmes-incendies         4
# 2        9 2015-01-03 21:07:00           1-REPOND         4
# 3       37 2015-01-03 21:41:46           1-REPOND         4
# 4       16 2015-01-03 21:43:32           SANS FEU        11
#
#        INCIDENT_TYPE_DESC   LATITUDE  LONGITUDE  NOMBRE_UNITES  \
# 0       Premier répondant  45.458786 -73.596117            1.0
# 1  Alarme privé ou locale  45.583442 -73.572020            4.0
# 2       Premier répondant  45.560784 -73.596589            1.0
# 3       Premier répondant  45.543197 -73.628847            1.0
# 4    Aliments surchauffés  45.522895 -73.580573            5.0
#
#                               NOM_ARROND NOM_VILLE  MONTH  DAY_OF_WEEK  \
# 0                              Sud-Ouest  Montréal      1            5
# 1                          Saint-Léonard  Montréal      1            5
# 2  Villeray / St-Michel / Parc Extension  Montréal      1            5
# 3  Villeray / St-Michel / Parc Extension  Montréal      1            5
# 4                     Plateau Mont-Royal  Montréal      1            5
#
#    HOUR_OF_DAY        Date TIME_OF_DAY
# 0           20  2015-01-03     Evening
# 1           21  2015-01-03     Evening
# 2           21  2015-01-03     Evening
# 3           21  2015-01-03     Evening
# 4           21  2015-01-03     Evening

# %%
# rename columns
df.rename(index=str, columns={"NOMBRE_UNITES": "NumUnits", "NOM_ARROND": "Arrond",
                              "MONTH": "Month", "DAY_OF_WEEK": "DayOfWeek",
                              "TIME_OF_DAY": "TimeOfDay"}, inplace=True)

# %%
columns_to_encode = ['Arrond', 'TimeOfDay']

# %%
def create_encoder_decoder(df, cols):
    "Returns encoder and decoder for provided columns."
    encoder = {}
    for col in cols:
        cats = pd.Categorical(df[col]).categories
        d = {}
        for i, cat in enumerate(cats):
            d[cat] = i
        encoder[col] = d
    
    decoder = {}
    for col, d in encoder.items():
        decoder[col] = {v:k for k, v in d.items()}
        
    return encoder, decoder

def write_dict_to_file(d, filename='temp.csv'):
    with open(filename, 'w') as csv_file:
        writer = csv.writer(csv_file)
        for key, value in d.items():
            writer.writerow([key, value])
            
def read_dict_from_file(filename='temp.csv'):
    with open(filename) as csv_file:
        reader = csv.reader(csv_file)
        d = dict(reader)
        return d

def encode_columns(df, encoder):
    df.replace(encoder, inplace=True)

def decode_columns(df, decoder):
    df.replace(decoder, inplace=True)

# %%
encoder, decoder = create_encoder_decoder(df, columns_to_encode)
write_dict_to_file(encoder, filename='encoder_arrond_tod.csv')
write_dict_to_file(decoder, filename='decoder_arrond_tod.csv')
encode_columns(df, encoder)

# %%
# to decode arrondisement and time of day, use the following code
#read_dict_from_file(filename='decoder_arrond_tod.csv')
#decode_columns(df, decoder)
#df.head()

# %%
# drop columns that aren't required
df.drop(['CREATION_DATE_TIME', 'INCIDENT_TYPE_DESC', 'LATITUDE', 'LONGITUDE',
        'CASERNE', 'DESCRIPTION_GROUPE', 'DIVISION', 'NOM_VILLE', 'HOUR_OF_DAY'],
        axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# NumUnits     563
# Arrond         0
# Month          0
# DayOfWeek      0
# Date           0
# TimeOfDay      0
# dtype: int64

# %%
# drop rows where number of units is NA
df.drop(df.loc[df['NumUnits'].isnull()].index, inplace=True)

# %%
df.head()
# Out:
#    NumUnits  Arrond  Month  DayOfWeek        Date  TimeOfDay
# 0       1.0      38      1          5  2015-01-03          3
# 1       4.0      33      1          5  2015-01-03          3
# 2       1.0      43      1          5  2015-01-03          3
# 3       1.0      43      1          5  2015-01-03          3
# 4       5.0      27      1          5  2015-01-03          3

# %%
#write to file
df.to_pickle('incident_data.pkl')
